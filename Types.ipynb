# %%
x = 5

# %%
x
# Out:
# 5

# %%
type(x)
# Out:
# int

# %%
y = 3

# %%
a = x * y
b = x / y
print a, b
# Out:
# 15 1

# %%
x = -5
b = x / y
print b
# Out:
# -2

# %%
bool('')
# Out:
# False

# %%
a = range(10000000)
a = set(a)
type(a)
# Out:
# set

# %%
# %%time
9999999 in a
# Out:
# Wall time: 0 ns
# True

# %%
a.append('as')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-74eabbfecb57> in <module>()
# ----> 1 a.append('as')
#
# AttributeError: 'set' object has no attribute 'append'

# %%
print a
# Out:
# [0, 1, 3, 4, 5, 6, 7, 8, 9, 10, 'as']

# %%
print a[2:9:2]
# Out:
# [2, 4, 6, 8]

# %%
a = u'фывф'
print a
type(a)
# Out:
# фывф
# unicode

# %%
hw = 'Hello, world!'.split(',')

# %%
'_'.join(hw)
# Out:
# 'Hello_ world!'

# %%
a = ('moscow', 'paris')
type(a)
a.append('london')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-f1ecf55c34f0> in <module>()
#       1 a = ('moscow', 'paris')
#       2 type(a)
# ----> 3 a.append('london')
#
# AttributeError: 'tuple' object has no attribute 'append'
